# %%
# Cell 1 — Imports and environment verification
# model_01_prior_specification.ipynb
# Day 20: translate prior_specification_draft.md into PyMC prior distributions.
# No fitting. No pm.sample(). Every pm. call cites its spec section.

import numpy as np
import pymc as pm
import pytensor.tensor as pt
import arviz as az
import matplotlib.pyplot as plt

print(f"PyMC version      : {pm.__version__}")
print(f"ArviZ version     : {az.__version__}")
print(f"NumPy version     : {np.__version__}")

print("\nEnvironment check passed. No fitting occurs in this notebook.")
# Out:
# ---------------------------------------------------------------------------
# NoSectionError                            Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.8/site-packages/pytensor/configparser.py:201, in PyTensorConfigParser.fetch_val_for_key(self, key, delete_key)
#     200 try:
# --> 201     return self._pytensor_cfg.get(section, option)
#     202 except InterpolationError:
#
# File /opt/anaconda3/lib/python3.8/configparser.py:781, in RawConfigParser.get(self, section, option, raw, vars, fallback)
#     780 try:
# --> 781     d = self._unify_values(section, vars)
#     782 except NoSectionError:
#
# File /opt/anaconda3/lib/python3.8/configparser.py:1149, in RawConfigParser._unify_values(self, section, vars)
#    1148     if section != self.default_section:
# -> 1149         raise NoSectionError(section) from None
#    1150 # Update with the entry specific variables
#
# NoSectionError: No section: 'blas'
#
# ...

# %%
# Cell 1 — minimal import test
import numpy as np
print(f"NumPy: {np.__version__}")

import pytensor
print(f"PyTensor: {pytensor.__version__}")
# Out:
# NumPy: 1.24.4
